# %%
import numpy as np

actual_values = np.array([100, 150, 200, 250])
predicted_values = np.array([90, 140, 180, 270])

mae = np.mean(np.abs(actual_values - predicted_values))
mse = np.mean((actual_values - predicted_values) ** 2)

# %%
print("Фактические значения:", actual_values)
print("Предсказанные значения:", predicted_values)
print("\nСредняя абсолютная ошибка (MAE):", mae)
print("Среднеквадратичная ошибка (MSE):", mse)
# Out:
# Фактические значения: [100 150 200 250]
# Предсказанные значения: [ 90 140 180 270]
#
# Средняя абсолютная ошибка (MAE): 15.0
# Среднеквадратичная ошибка (MSE): 250.0
